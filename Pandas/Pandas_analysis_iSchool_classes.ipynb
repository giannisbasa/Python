# %% [markdown]
# #### Data Analysis with Pandas

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# read all 5 pages of the schedule into a single pandas dataframe
# figure out which are grad which are undergrad
# display the undergrad 8am classes
# display the undergrad friday classes

# %%
# we will get back a list and inside the list there is a df
website = 'https://ischool.syr.edu/classes/'
datalist = pd.read_html(website)
page_1 = datalist[0]

# %%
# let's generate links to the other pages
website = 'https://ischool.syr.edu/classes/?page='
for i in range(1,6):
    link = website + str(i)
    print(link)
# Out:
# https://ischool.syr.edu/classes/?page=1
# https://ischool.syr.edu/classes/?page=2
# https://ischool.syr.edu/classes/?page=3
# https://ischool.syr.edu/classes/?page=4
# https://ischool.syr.edu/classes/?page=5

# %%
# let's read them all and append them to a single data frame

website = 'https://ischool.syr.edu/classes/?page='
classes = pd.DataFrame() #  (columns = ['Course','Section','ClassNo','Credits','Title','Instructor','Time','Days','Room'])

for i in range(1,6):
    link = website + str(i)
    data = pd.read_html(website + str(i))
    classes = classes.append(data[0], ignore_index = True)
classes.sample(5)

# Set the columns. If we want to set the name column at ones
# classes.columns = ['Course','Section','ClassNo','Credits','Title','Instructor','Time','Days','Room']
# Out:
#      Course Section  Class  Credits                              Title  \
# 39   IST300    M002  37853      3.0        Information Security Policy
# 28   IST233    M006  37666      3.0  LAB: Intro to Computer Networking
# 10   IDS660    M003  37759      3.0     Spring Break in Silicon Valley
# 172  IST664    M001  37701      3.0        Natural Language Processing
# 198  IST707    M405  37909      3.0                     Data Analytics
#
#          Instructor(s)               Time   Day                Room(s)
# 39      James Enwright    6:30pm - 7:50pm  TuTh  Hall of Languages 114
# 28    S Bruce Boardman    1:50pm - 2:45pm     F         Hinds Hall 027
# 10   John DuRoss Liddy  12:00am - 12:00am   NaN                    NaN
# 172            Lu Xiao    2:00pm - 4:45pm    Th         Hinds Hall 010
# 198    Jeremy P Bolton   12:00am - 4:00pm    Su         Online  Online

# %%
classes.shape
# Out:
# (244, 9)

# %%
# undergrad classes are 0-499, grad classes are 500 and up but we don't have 
# course numbers!!!! So we must engineer them.


classes['Course_num'] = classes.Course.str[3:]

# we will create a new column for the type of the course
# if the course num is below 500 is undergrand otherwise is grand course
classes['Type'] = 'none'
classes = classes[['Course','Course_num','Type','Section','ClassNo','Credits','Title','Instructor','Time','Days','Room']]


classes['Course_num'] = classes.Course.str[3:]
classes['Type'] = 'none'
classes['Type'][classes['Course_num'] < '500'] = 'Undergrad'
classes['Type'][classes['Course_num'] >= '500'] = 'Grand'

classes.sample(5)
# Out:
#      Course Course_num       Type Section  ClassNo  Credits  \
# 232  IST810        810      Grand    M002    37710      2.0
# 116  IST605        605      Grand    M405    37788      3.0
# 199  IST707        707      Grand    M406    37910      3.0
# 64   IST349        349  Undergrad    M001    37634      3.0
# 89   IST455        455  Undergrad    M001    42590      3.0
#
#                               Title            Instructor               Time  \
# 232           Practicum in Research       Steven B Sawyer   9:30am - 11:25am
# 116  Reference& Info Literacy Svces  Amanda Bucher Albert   12:00am - 8:30pm
# 199                  Data Analytics              Ying Lin  12:00am - 10:30pm
# 64          Human Comp. Interaction    Natalie C. LoRusso   12:30pm - 1:50pm
# 89       Enterprise IT Consultation      Frank Jr Marullo    3:30pm - 4:50pm
#
#      Days            Room
# 232    Tu  Hinds Hall 120
# 116     W  Online  Online
# 199     W  Online  Online
# 64   TuTh  Hinds Hall 111
# 89   TuTh  Hinds Hall 011

# %%
# let's find the number of grad / undergrad courses
classes.Type.value_counts()
# Out:
# Grand        146
# Undergrad     98
# Name: Type, dtype: int64

# %%
# how many undergrad classes on a Friday?
fridays = classes[(classes.Days.str.find('F')>=0) & (classes.Type == 'Undergrad')]
fridays.sample(5)
# Out:
#     Course Course_num       Type Section  ClassNo  Credits  \
# 15  IST195        195  Undergrad    M004    37659      3.0
# 6   IDS403        403  Undergrad    M001    37649      1.0
# 7   IDS460        460  Undergrad    M002    37755      3.0
# 18  IST195        195  Undergrad    M007    37662      3.0
# 16  IST195        195  Undergrad    M005    37660      3.0
#
#                             Title         Instructor               Time  \
# 15  LAB: Information Technologies         Jeff Rubin  10:35am - 11:30am
# 6                 Startup Sandbox  John DuRoss Liddy    2:15pm - 5:05pm
# 7                 Entretech - NYC  John DuRoss Liddy  12:00am - 12:00am
# 18  LAB: Information Technologies         Jeff Rubin    1:50pm - 2:45pm
# 16  LAB: Information Technologies         Jeff Rubin  11:40am - 12:35pm
#
#        Days                                           Room
# 15        F                                 Hinds Hall 010
# 6         F                     Syracuse Technology Garden
# 7   MTuWThF  Courtyard Marriott Man Midtwn  Online  Online
# 18        F                                 Hinds Hall 010
# 16        F                                 Hinds Hall 010

# %%
# how many undergrad classes on a Friday?
friday_no_lab = fridays[~fridays.Title.str.startswith('LAB:')]
friday_no_lab
# Out:
#     Course Course_num       Type Section  ClassNo  Credits  \
# 6   IDS403        403  Undergrad    M001    37649      1.0
# 7   IDS460        460  Undergrad    M002    37755      3.0
# 8   IDS460        460  Undergrad    M003    37756      3.0
# 48  IST337        337  Undergrad    M001    37848      1.0
# 99  IST486        486  Undergrad    M002    42625      3.0
#
#                              Title               Instructor  \
# 6                  Startup Sandbox        John DuRoss Liddy
# 7                  Entretech - NYC        John DuRoss Liddy
# 8   Spring Break in Silicon Valley        John DuRoss Liddy
# 48          IM&T Support Practicum            Jeffrey Fouts
# 99    Social Media in the Organiz.  Kristy Lee Hochenberger
#
#                  Time       Days  \
# 6     2:15pm - 5:05pm          F
# 7   12:00am - 12:00am    MTuWThF
# 8   12:00am - 12:00am  MTuWThFSu
# 48    2:15pm - 5:00pm          F
# 99   9:30am - 10:25am        MWF
#
#                                               Room
# 6                       Syracuse Technology Garden
# 7    Courtyard Marriott Man Midtwn  Online  Online
# 8   Online  Online  Residence Inn by Marr, San Mat
# 48                                  Hinds Hall 117
# 99                                  Hinds Hall 021

# %%
# 8AM classes
eight_am = classes[ classes['Time'].str.startswith('8:00am')]
eight_am
# Out:
#     Course Course_num       Type Section  ClassNo  Credits  \
# 68  IST352        352  Undergrad    M006    37688      3.0
# 91  IST466        466  Undergrad    M001    37621      3.0
#
#                             Title          Instructor             Time  Days  \
# 68  Info Analysis of Org. Systems  Alexander Corsello  8:00am - 9:20am  TuTh
# 91   Prof Issues/Info Mgmt & Tech        Bruce Kingma  8:00am - 9:20am    MW
#
#               Room
# 68  Hinds Hall 117
# 91  Hinds Hall 243
